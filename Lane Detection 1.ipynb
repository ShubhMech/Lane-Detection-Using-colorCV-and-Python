# %%
import cv2, numpy as np, matplotlib.pyplot as plt, matplotlib.image as img_

# %%
path=r"D:\Asus\Documents\Many-underestimate-white-dashed-lines.jpg"

# %%
col_img= img_.imread(path)

# %%
plt.imshow(col_img)

# %%
bnw= cv2.cvtColor(col_img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(bnw, cmap="gray")

# %%
bnw.shape
# Out:
# (427, 640)

# %%
img_copy= np.copy(bnw)

# %%
img_copy
# Out:
# array([[250, 250, 250, ..., 253, 253, 253],
#        [250, 250, 250, ..., 253, 253, 253],
#        [250, 250, 250, ..., 253, 253, 253],
#        ...,
#        [ 96, 100,  90, ...,  82, 114,  91],
#        [ 69,  88, 103, ...,  88, 113,  99],
#        [ 94,  93,  83, ...,  96, 111, 109]], dtype=uint8)

# %%
img_copy.shape
# Out:
# (427, 640)

# %%
plt.imshow(img_copy, cmap="gray")

# %%
img_copy<250
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
result=img_copy<250

# %%
(result[:,:]==False).sum()
# Out:
# 54855

# %%
img_copy[result]=0

# %%
plt.imshow(img_copy, cmap="gray")
